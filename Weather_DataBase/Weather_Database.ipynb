# %%
#import the requests library
import requests

#import the API key
from config import weather_api_key

# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        weather_disc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Current Description": weather_disc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | tunduru
# City not found. Skipping...
# Processing Record 3 of Set 1 | severo-kurilsk
# Processing Record 4 of Set 1 | lorengau
# Processing Record 5 of Set 1 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 6 of Set 1 | tiszaluc
# Processing Record 7 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 1 | kijang
# Processing Record 9 of Set 1 | sola
# Processing Record 10 of Set 1 | kailua
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | georgetown
# Processing Record 13 of Set 1 | toftir
# City not found. Skipping...
# Processing Record 14 of Set 1 | ciudad bolivar
# Processing Record 15 of Set 1 | yellowknife
# Processing Record 16 of Set 1 | montepuez
# Processing Record 17 of Set 1 | omsukchan
# Processing Record 18 of Set 1 | hilo
# Processing Record 19 of Set 1 | yanam
# Processing Record 20 of Set 1 | mazyr
# Processing Record 21 of Set 1 | kodiak
# Processing Record 22 of Set 1 | quatre cocos
# Processing Record 23 of Set 1 | tiksi
# Processing Record 24 of Set 1 | belaya gora
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | pasni
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | noumea
# Processing Record 30 of Set 1 | port elizabeth
# Processing Record 31 of Set 1 | erenhot
# Processing Record 32 of Set 1 | bandarbeyla
# Processing Record 33 of Set 1 | cidreira
# Processing Record 34 of Set 1 | thompson
# Processing Record 35 of Set 1 | atambua
# Processing Record 36 of Set 1 | point fortin
# Processing Record 37 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 1 | nikolskoye
# Processing Record 39 of Set 1 | huntsville
# Processing Record 40 of Set 1 | san quintin
# Processing Record 41 of Set 1 | council bluffs
# Processing Record 42 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 1 | arraial do cabo
# Processing Record 44 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 1 | sakakah
# Processing Record 46 of Set 1 | grindavik
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | karkaralinsk
# City not found. Skipping...
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 50 of Set 1 | chuy
# Processing Record 1 of Set 2 | honningsvag
# Processing Record 2 of Set 2 | hobart
# Processing Record 3 of Set 2 | mengcheng
# Processing Record 4 of Set 2 | aguimes
# Processing Record 5 of Set 2 | haines junction
# Processing Record 6 of Set 2 | bambous virieux
# Processing Record 7 of Set 2 | rikitea
# Processing Record 8 of Set 2 | nemuro
# Processing Record 9 of Set 2 | castro
# Processing Record 10 of Set 2 | grand gaube
# Processing Record 11 of Set 2 | ushuaia
# Processing Record 12 of Set 2 | mataura
# Processing Record 13 of Set 2 | along
# Processing Record 14 of Set 2 | catamarca
# Processing Record 15 of Set 2 | banda aceh
# Processing Record 16 of Set 2 | havre-saint-pierre
# Processing Record 17 of Set 2 | hudson bay
# Processing Record 18 of Set 2 | nanortalik
# Processing Record 19 of Set 2 | tuatapere
# Processing Record 20 of Set 2 | dikson
# Processing Record 21 of Set 2 | plettenberg bay
# Processing Record 22 of Set 2 | busselton
# Processing Record 23 of Set 2 | klaksvik
# Processing Record 24 of Set 2 | upernavik
# Processing Record 25 of Set 2 | tual
# Processing Record 26 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 2 | dubna
# Processing Record 28 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 29 of Set 2 | vaini
# Processing Record 30 of Set 2 | kahului
# Processing Record 31 of Set 2 | port blair
# Processing Record 32 of Set 2 | makakilo city
# Processing Record 33 of Set 2 | sayat
# Processing Record 34 of Set 2 | bredasdorp
# Processing Record 35 of Set 2 | kirando
# Processing Record 36 of Set 2 | kamina
# Processing Record 37 of Set 2 | garni
# Processing Record 38 of Set 2 | east london
# Processing Record 39 of Set 2 | iqaluit
# Processing Record 40 of Set 2 | broome
# Processing Record 41 of Set 2 | kodarma
# Processing Record 42 of Set 2 | valdosta
# Processing Record 43 of Set 2 | ostrovnoy
# Processing Record 44 of Set 2 | tarakan
# Processing Record 45 of Set 2 | kedrovyy
# Processing Record 46 of Set 2 | caledon
# Processing Record 47 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 48 of Set 2 | ginir
# Processing Record 49 of Set 2 | sept-iles
# Processing Record 50 of Set 2 | new norfolk
# Processing Record 1 of Set 3 | bethel
# Processing Record 2 of Set 3 | te anau
# Processing Record 3 of Set 3 | rochelle
# Processing Record 4 of Set 3 | dranic
# City not found. Skipping...
# Processing Record 5 of Set 3 | aklavik
# Processing Record 6 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 3 | kapaa
# Processing Record 8 of Set 3 | faanui
# Processing Record 9 of Set 3 | guerrero negro
# Processing Record 10 of Set 3 | mwene-ditu
# Processing Record 11 of Set 3 | ilulissat
# Processing Record 12 of Set 3 | acarau
# Processing Record 13 of Set 3 | shimoda
# Processing Record 14 of Set 3 | pyapon
# Processing Record 15 of Set 3 | leningradskiy
# Processing Record 16 of Set 3 | saldanha
# Processing Record 17 of Set 3 | kruisfontein
# Processing Record 18 of Set 3 | dingle
# Processing Record 19 of Set 3 | jamestown
# Processing Record 20 of Set 3 | sohbatpur
# Processing Record 21 of Set 3 | salamiyah
# Processing Record 22 of Set 3 | namatanai
# Processing Record 23 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 24 of Set 3 | matara
# Processing Record 25 of Set 3 | chokurdakh
# Processing Record 26 of Set 3 | yulara
# Processing Record 27 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 3 | san vicente
# Processing Record 29 of Set 3 | hatillo
# Processing Record 30 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 3 | morris
# Processing Record 32 of Set 3 | wuan
# Processing Record 33 of Set 3 | skibbereen
# Processing Record 34 of Set 3 | muncar
# Processing Record 35 of Set 3 | okhotsk
# Processing Record 36 of Set 3 | vardo
# Processing Record 37 of Set 3 | hithadhoo
# Processing Record 38 of Set 3 | saskylakh
# Processing Record 39 of Set 3 | avarua
# Processing Record 40 of Set 3 | ponta do sol
# Processing Record 41 of Set 3 | tasiilaq
# Processing Record 42 of Set 3 | lazaro cardenas
# Processing Record 43 of Set 3 | mahebourg
# Processing Record 44 of Set 3 | coquimbo
# Processing Record 45 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 3 | bosobolo
# Processing Record 47 of Set 3 | flinders
# Processing Record 48 of Set 3 | port alfred
# Processing Record 49 of Set 3 | huarmey
# Processing Record 50 of Set 3 | asfi
# Processing Record 1 of Set 4 | fomboni
# Processing Record 2 of Set 4 | pimentel
# Processing Record 3 of Set 4 | aitape
# Processing Record 4 of Set 4 | beira
# Processing Record 5 of Set 4 | houma
# Processing Record 6 of Set 4 | kaitangata
# Processing Record 7 of Set 4 | unai
# Processing Record 8 of Set 4 | pandan
# Processing Record 9 of Set 4 | bonavista
# Processing Record 10 of Set 4 | hasaki
# Processing Record 11 of Set 4 | sogdiondon
# City not found. Skipping...
# Processing Record 12 of Set 4 | dolores
# Processing Record 13 of Set 4 | tocopilla
# Processing Record 14 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 4 | galle
# Processing Record 16 of Set 4 | college
# Processing Record 17 of Set 4 | warri
# Processing Record 18 of Set 4 | bathsheba
# Processing Record 19 of Set 4 | raudeberg
# Processing Record 20 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 4 | maykain
# City not found. Skipping...
# Processing Record 22 of Set 4 | cap malheureux
# Processing Record 23 of Set 4 | ashington
# Processing Record 24 of Set 4 | ulaanbaatar
# Processing Record 25 of Set 4 | orsha
# Processing Record 26 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 27 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 4 | kargasok
# Processing Record 29 of Set 4 | kudahuvadhoo
# Processing Record 30 of Set 4 | skegness
# Processing Record 31 of Set 4 | teguise
# Processing Record 32 of Set 4 | sibolga
# Processing Record 33 of Set 4 | manadhoo
# Processing Record 34 of Set 4 | khatanga
# Processing Record 35 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 36 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 37 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 4 | eureka
# Processing Record 39 of Set 4 | port-gentil
# Processing Record 40 of Set 4 | carnarvon
# Processing Record 41 of Set 4 | meadow lake
# Processing Record 42 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 43 of Set 4 | japura
# Processing Record 44 of Set 4 | daru
# Processing Record 45 of Set 4 | yanchukan
# City not found. Skipping...
# Processing Record 46 of Set 4 | samarai
# Processing Record 47 of Set 4 | puerto ayora
# Processing Record 48 of Set 4 | snezhnogorsk
# Processing Record 49 of Set 4 | kannauj
# Processing Record 50 of Set 4 | koslan
# Processing Record 1 of Set 5 | taltal
# Processing Record 2 of Set 5 | sosnovo-ozerskoye
# Processing Record 3 of Set 5 | coihaique
# Processing Record 4 of Set 5 | pevek
# Processing Record 5 of Set 5 | axim
# Processing Record 6 of Set 5 | jaslo
# Processing Record 7 of Set 5 | hami
# Processing Record 8 of Set 5 | havelock
# Processing Record 9 of Set 5 | morant bay
# Processing Record 10 of Set 5 | mar del plata
# Processing Record 11 of Set 5 | barrow
# Processing Record 12 of Set 5 | san cristobal
# Processing Record 13 of Set 5 | yeppoon
# Processing Record 14 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 15 of Set 5 | calamar
# Processing Record 16 of Set 5 | clyde river
# Processing Record 17 of Set 5 | laguna de perlas
# Processing Record 18 of Set 5 | victoria
# Processing Record 19 of Set 5 | antalaha
# Processing Record 20 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 5 | bari sadri
# Processing Record 22 of Set 5 | ossora
# Processing Record 23 of Set 5 | coos bay
# Processing Record 24 of Set 5 | luderitz
# Processing Record 25 of Set 5 | chapais
# Processing Record 26 of Set 5 | vrangel
# Processing Record 27 of Set 5 | gari
# Processing Record 28 of Set 5 | soyo
# Processing Record 29 of Set 5 | dukat
# Processing Record 30 of Set 5 | mahibadhoo
# Processing Record 31 of Set 5 | viedma
# Processing Record 32 of Set 5 | geraldton
# Processing Record 33 of Set 5 | bengkulu
# Processing Record 34 of Set 5 | scottsburgh
# City not found. Skipping...
# Processing Record 35 of Set 5 | leeton
# Processing Record 36 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 37 of Set 5 | biak
# Processing Record 38 of Set 5 | pangnirtung
# Processing Record 39 of Set 5 | lincoln
# Processing Record 40 of Set 5 | denia
# Processing Record 41 of Set 5 | texarkana
# Processing Record 42 of Set 5 | luba
# Processing Record 43 of Set 5 | den helder
# Processing Record 44 of Set 5 | codrington
# Processing Record 45 of Set 5 | camana
# Processing Record 46 of Set 5 | cabo san lucas
# Processing Record 47 of Set 5 | rawson
# Processing Record 48 of Set 5 | watertown
# Processing Record 49 of Set 5 | husavik
# Processing Record 50 of Set 5 | skagastrond
# City not found. Skipping...
# Processing Record 1 of Set 6 | acari
# Processing Record 2 of Set 6 | camacha
# Processing Record 3 of Set 6 | victor harbor
# Processing Record 4 of Set 6 | saint-pierre
# Processing Record 5 of Set 6 | saint-esteve
# Processing Record 6 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 7 of Set 6 | buraydah
# Processing Record 8 of Set 6 | lagunas
# Processing Record 9 of Set 6 | ribeira grande
# Processing Record 10 of Set 6 | kavieng
# Processing Record 11 of Set 6 | aiyina
# City not found. Skipping...
# Processing Record 12 of Set 6 | ahar
# Processing Record 13 of Set 6 | arauca
# Processing Record 14 of Set 6 | srednekolymsk
# Processing Record 15 of Set 6 | san ignacio
# Processing Record 16 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 6 | coahuayana
# Processing Record 18 of Set 6 | nagato
# Processing Record 19 of Set 6 | karamea
# City not found. Skipping...
# Processing Record 20 of Set 6 | benidorm
# Processing Record 21 of Set 6 | ishigaki
# Processing Record 22 of Set 6 | jaque
# Processing Record 23 of Set 6 | wattegama
# Processing Record 24 of Set 6 | williston
# Processing Record 25 of Set 6 | asau
# Processing Record 26 of Set 6 | atuona
# Processing Record 27 of Set 6 | sarangani
# Processing Record 28 of Set 6 | tuktoyaktuk
# Processing Record 29 of Set 6 | touros
# Processing Record 30 of Set 6 | ambilobe
# Processing Record 31 of Set 6 | da nang
# Processing Record 32 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 33 of Set 6 | sande
# Processing Record 34 of Set 6 | norman wells
# Processing Record 35 of Set 6 | brae
# Processing Record 36 of Set 6 | jishu
# Processing Record 37 of Set 6 | dongsheng
# Processing Record 38 of Set 6 | airai
# Processing Record 39 of Set 6 | barra do bugres
# Processing Record 40 of Set 6 | fortuna
# Processing Record 41 of Set 6 | pundaguitan
# Processing Record 42 of Set 6 | maceio
# Processing Record 43 of Set 6 | dengzhou
# Processing Record 44 of Set 6 | pavlogradka
# Processing Record 45 of Set 6 | monte carmelo
# Processing Record 46 of Set 6 | namtsy
# Processing Record 47 of Set 6 | crowley
# Processing Record 48 of Set 6 | tautira
# Processing Record 49 of Set 6 | antofagasta
# Processing Record 50 of Set 6 | portobelo
# Processing Record 1 of Set 7 | portland
# Processing Record 2 of Set 7 | dunedin
# Processing Record 3 of Set 7 | sobolevo
# Processing Record 4 of Set 7 | pangai
# Processing Record 5 of Set 7 | nouadhibou
# Processing Record 6 of Set 7 | san patricio
# Processing Record 7 of Set 7 | lebu
# Processing Record 8 of Set 7 | qandahar
# City not found. Skipping...
# Processing Record 9 of Set 7 | cherskiy
# Processing Record 10 of Set 7 | adrar
# Processing Record 11 of Set 7 | paysandu
# Processing Record 12 of Set 7 | lompoc
# Processing Record 13 of Set 7 | omboue
# Processing Record 14 of Set 7 | santa maria
# Processing Record 15 of Set 7 | mendi
# Processing Record 16 of Set 7 | miguel auza
# Processing Record 17 of Set 7 | ouesso
# Processing Record 18 of Set 7 | terrell
# Processing Record 19 of Set 7 | alingsas
# Processing Record 20 of Set 7 | san policarpo
# Processing Record 21 of Set 7 | richards bay
# Processing Record 22 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 23 of Set 7 | moron
# Processing Record 24 of Set 7 | mayo
# Processing Record 25 of Set 7 | cayenne
# Processing Record 26 of Set 7 | wanning
# Processing Record 27 of Set 7 | enugu
# Processing Record 28 of Set 7 | mehamn
# Processing Record 29 of Set 7 | nome
# Processing Record 30 of Set 7 | abu kamal
# Processing Record 31 of Set 7 | fort nelson
# Processing Record 32 of Set 7 | dhidhdhoo
# Processing Record 33 of Set 7 | kiunga
# Processing Record 34 of Set 7 | sao francisco
# Processing Record 35 of Set 7 | muros
# Processing Record 36 of Set 7 | coro
# Processing Record 37 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 38 of Set 7 | santa cruz del sur
# Processing Record 39 of Set 7 | saint george
# Processing Record 40 of Set 7 | pontes e lacerda
# Processing Record 41 of Set 7 | cumberland
# Processing Record 42 of Set 7 | hammerfest
# Processing Record 43 of Set 7 | turkmenabat
# Processing Record 44 of Set 7 | maridi
# Processing Record 45 of Set 7 | albania
# Processing Record 46 of Set 7 | puerto escondido
# Processing Record 47 of Set 7 | zharkovskiy
# Processing Record 48 of Set 7 | massape
# Processing Record 49 of Set 7 | iberia
# Processing Record 50 of Set 7 | bartica
# Processing Record 1 of Set 8 | benguela
# Processing Record 2 of Set 8 | pozega
# Processing Record 3 of Set 8 | omaruru
# Processing Record 4 of Set 8 | pathein
# Processing Record 5 of Set 8 | bacuit
# City not found. Skipping...
# Processing Record 6 of Set 8 | abu jubayhah
# City not found. Skipping...
# Processing Record 7 of Set 8 | faya
# Processing Record 8 of Set 8 | vastseliina
# Processing Record 9 of Set 8 | longyearbyen
# Processing Record 10 of Set 8 | maniitsoq
# Processing Record 11 of Set 8 | sur
# Processing Record 12 of Set 8 | aksarka
# Processing Record 13 of Set 8 | waddan
# Processing Record 14 of Set 8 | mega
# Processing Record 15 of Set 8 | port lincoln
# Processing Record 16 of Set 8 | harper
# Processing Record 17 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 8 | bira
# Processing Record 19 of Set 8 | paranagua
# Processing Record 20 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 21 of Set 8 | kefamenanu
# Processing Record 22 of Set 8 | tura
# Processing Record 23 of Set 8 | xining
# Processing Record 24 of Set 8 | khartoum
# Processing Record 25 of Set 8 | saint-philippe
# Processing Record 26 of Set 8 | port macquarie
# Processing Record 27 of Set 8 | evensk
# Processing Record 28 of Set 8 | ponta delgada
# Processing Record 29 of Set 8 | mattawa
# Processing Record 30 of Set 8 | fort madison
# Processing Record 31 of Set 8 | murliganj
# Processing Record 32 of Set 8 | constitucion
# Processing Record 33 of Set 8 | simao
# Processing Record 34 of Set 8 | lavrentiya
# Processing Record 35 of Set 8 | jodhpur
# Processing Record 36 of Set 8 | karlstad
# Processing Record 37 of Set 8 | berlevag
# Processing Record 38 of Set 8 | puerto ayacucho
# Processing Record 39 of Set 8 | ucluelet
# Processing Record 40 of Set 8 | sakhnovshchyna
# Processing Record 41 of Set 8 | mocuba
# Processing Record 42 of Set 8 | olinda
# Processing Record 43 of Set 8 | udachnyy
# Processing Record 44 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 45 of Set 8 | bosaso
# Processing Record 46 of Set 8 | yatou
# Processing Record 47 of Set 8 | ambon
# Processing Record 48 of Set 8 | ganzhou
# Processing Record 49 of Set 8 | murgab
# Processing Record 50 of Set 8 | saint-augustin
# Processing Record 1 of Set 9 | morro bay
# Processing Record 2 of Set 9 | san rafael
# Processing Record 3 of Set 9 | mouzouras
# Processing Record 4 of Set 9 | westport
# Processing Record 5 of Set 9 | kiruna
# Processing Record 6 of Set 9 | kuanhsi
# City not found. Skipping...
# Processing Record 7 of Set 9 | los llanos de aridane
# Processing Record 8 of Set 9 | simbahan
# Processing Record 9 of Set 9 | gravdal
# Processing Record 10 of Set 9 | severo-yeniseyskiy
# Processing Record 11 of Set 9 | anloga
# Processing Record 12 of Set 9 | vizinga
# Processing Record 13 of Set 9 | kununurra
# Processing Record 14 of Set 9 | villanueva
# Processing Record 15 of Set 9 | tiruchchendur
# Processing Record 16 of Set 9 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 9 | kyren
# Processing Record 18 of Set 9 | sapucaia
# Processing Record 19 of Set 9 | banjar
# Processing Record 20 of Set 9 | vuktyl
# Processing Record 21 of Set 9 | saint anthony
# Processing Record 22 of Set 9 | katsuura
# Processing Record 23 of Set 9 | monticello
# Processing Record 24 of Set 9 | burica
# City not found. Skipping...
# Processing Record 25 of Set 9 | cubuk
# Processing Record 26 of Set 9 | borlange
# City not found. Skipping...
# Processing Record 27 of Set 9 | banmo
# City not found. Skipping...
# Processing Record 28 of Set 9 | cabedelo
# Processing Record 29 of Set 9 | gergebil
# Processing Record 30 of Set 9 | burnie
# Processing Record 31 of Set 9 | kachiry
# Processing Record 32 of Set 9 | singkang
# Processing Record 33 of Set 9 | fukue
# Processing Record 34 of Set 9 | danjiangkou
# Processing Record 35 of Set 9 | ketchikan
# Processing Record 36 of Set 9 | kirundo
# Processing Record 37 of Set 9 | pelotas
# Processing Record 38 of Set 9 | villarrica
# Processing Record 39 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 40 of Set 9 | byron bay
# Processing Record 41 of Set 9 | capitan bado
# Processing Record 42 of Set 9 | desbiens
# Processing Record 43 of Set 9 | manokwari
# Processing Record 44 of Set 9 | naryan-mar
# Processing Record 45 of Set 9 | puerto del rosario
# Processing Record 46 of Set 9 | villazon
# Processing Record 47 of Set 9 | talcahuano
# Processing Record 48 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 49 of Set 9 | yei
# Processing Record 50 of Set 9 | kautokeino
# Processing Record 1 of Set 10 | pacific grove
# Processing Record 2 of Set 10 | batemans bay
# Processing Record 3 of Set 10 | sitka
# Processing Record 4 of Set 10 | oster
# Processing Record 5 of Set 10 | ulladulla
# Processing Record 6 of Set 10 | baykit
# Processing Record 7 of Set 10 | itarema
# Processing Record 8 of Set 10 | pimenta bueno
# Processing Record 9 of Set 10 | naze
# Processing Record 10 of Set 10 | kupang
# Processing Record 11 of Set 10 | gulshat
# City not found. Skipping...
# Processing Record 12 of Set 10 | prince rupert
# Processing Record 13 of Set 10 | mbandaka
# Processing Record 14 of Set 10 | laguna
# Processing Record 15 of Set 10 | mnogovershinnyy
# Processing Record 16 of Set 10 | montague
# Processing Record 17 of Set 10 | santa vitoria do palmar
# Processing Record 18 of Set 10 | bondo
# Processing Record 19 of Set 10 | talnakh
# Processing Record 20 of Set 10 | la ronge
# Processing Record 21 of Set 10 | pitimbu
# Processing Record 22 of Set 10 | hinjilikatu
# Processing Record 23 of Set 10 | zamora
# Processing Record 24 of Set 10 | puerto carreno
# Processing Record 25 of Set 10 | alofi
# Processing Record 26 of Set 10 | mmabatho
# Processing Record 27 of Set 10 | qorveh
# Processing Record 28 of Set 10 | shingu
# Processing Record 29 of Set 10 | atbasar
# Processing Record 30 of Set 10 | abbeville
# Processing Record 31 of Set 10 | auki
# Processing Record 32 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 10 | gat
# Processing Record 34 of Set 10 | shimanovsk
# Processing Record 35 of Set 10 | mareeba
# Processing Record 36 of Set 10 | gallup
# Processing Record 37 of Set 10 | gediz
# Processing Record 38 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 39 of Set 10 | ahipara
# Processing Record 40 of Set 10 | yantai
# Processing Record 41 of Set 10 | gillette
# Processing Record 42 of Set 10 | tortoli
# Processing Record 43 of Set 10 | churapcha
# Processing Record 44 of Set 10 | miandrivazo
# Processing Record 45 of Set 10 | balikpapan
# Processing Record 46 of Set 10 | el vigia
# Processing Record 47 of Set 10 | epinal
# Processing Record 48 of Set 10 | bonthe
# Processing Record 49 of Set 10 | tabas
# Processing Record 50 of Set 10 | sokyryany
# Processing Record 1 of Set 11 | maua
# Processing Record 2 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 11 | tongliao
# Processing Record 4 of Set 11 | marzuq
# Processing Record 5 of Set 11 | augusto correa
# Processing Record 6 of Set 11 | monrovia
# Processing Record 7 of Set 11 | sisimiut
# Processing Record 8 of Set 11 | gamba
# Processing Record 9 of Set 11 | kamwenge
# Processing Record 10 of Set 11 | wasilla
# Processing Record 11 of Set 11 | suslovo
# Processing Record 12 of Set 11 | inirida
# Processing Record 13 of Set 11 | vila franca do campo
# Processing Record 14 of Set 11 | boa vista
# Processing Record 15 of Set 11 | blois
# Processing Record 16 of Set 11 | ormstown
# Processing Record 17 of Set 11 | otavi
# Processing Record 18 of Set 11 | avera
# Processing Record 19 of Set 11 | sao filipe
# Processing Record 20 of Set 11 | hvammstangi
# City not found. Skipping...
# Processing Record 21 of Set 11 | garissa
# Processing Record 22 of Set 11 | luancheng
# Processing Record 23 of Set 11 | skjervoy
# Processing Record 24 of Set 11 | korla
# Processing Record 25 of Set 11 | sofiysk
# City not found. Skipping...
# Processing Record 26 of Set 11 | medea
# Processing Record 27 of Set 11 | merke
# Processing Record 28 of Set 11 | vestmannaeyjar
# Processing Record 29 of Set 11 | kasongo-lunda
# Processing Record 30 of Set 11 | kokkola
# Processing Record 31 of Set 11 | tungor
# Processing Record 32 of Set 11 | lumberton
# Processing Record 33 of Set 11 | rincon
# Processing Record 34 of Set 11 | shieli
# Processing Record 35 of Set 11 | vestmanna
# Processing Record 36 of Set 11 | maues
# Processing Record 37 of Set 11 | hualmay
# Processing Record 38 of Set 11 | freeport
# Processing Record 39 of Set 11 | padang
# Processing Record 40 of Set 11 | sungai siput utara
# City not found. Skipping...
# Processing Record 41 of Set 11 | quelimane
# Processing Record 42 of Set 11 | benghazi
# Processing Record 43 of Set 11 | rosendal
# Processing Record 44 of Set 11 | corrales
# Processing Record 45 of Set 11 | phayao
# Processing Record 46 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 47 of Set 11 | kloulklubed
# Processing Record 48 of Set 11 | flin flon
# Processing Record 49 of Set 11 | waipawa
# Processing Record 50 of Set 11 | porto belo
# Processing Record 1 of Set 12 | torbay
# Processing Record 2 of Set 12 | bulgan
# Processing Record 3 of Set 12 | chimore
# Processing Record 4 of Set 12 | yima
# Processing Record 5 of Set 12 | makarov
# Processing Record 6 of Set 12 | sao joao da barra
# Processing Record 7 of Set 12 | necochea
# Processing Record 8 of Set 12 | atasu
# Processing Record 9 of Set 12 | hamilton
# Processing Record 10 of Set 12 | farafangana
# Processing Record 11 of Set 12 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 12 | karasuk
# Processing Record 13 of Set 12 | bedford
# Processing Record 14 of Set 12 | neuquen
# Processing Record 15 of Set 12 | azimur
# City not found. Skipping...
# Processing Record 16 of Set 12 | biggar
# Processing Record 17 of Set 12 | soe
# Processing Record 18 of Set 12 | sterling
# Processing Record 19 of Set 12 | cape coast
# Processing Record 20 of Set 12 | tungkang
# City not found. Skipping...
# Processing Record 21 of Set 12 | brownsville
# Processing Record 22 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 23 of Set 12 | dothan
# Processing Record 24 of Set 12 | rantepao
# Processing Record 25 of Set 12 | esperance
# Processing Record 26 of Set 12 | zavetnoye
# Processing Record 27 of Set 12 | mandalgovi
# Processing Record 28 of Set 12 | urumqi
# Processing Record 29 of Set 12 | skibotn
# Processing Record 30 of Set 12 | narsaq
# Processing Record 31 of Set 12 | limoges
# Processing Record 32 of Set 12 | seoul
# Processing Record 33 of Set 12 | kutum
# Processing Record 34 of Set 12 | rabo de peixe
# Processing Record 35 of Set 12 | cockburn harbour
# City not found. Skipping...
# Processing Record 36 of Set 12 | salym
# Processing Record 37 of Set 12 | corozal
# Processing Record 38 of Set 12 | torit
# Processing Record 39 of Set 12 | half moon bay
# Processing Record 40 of Set 12 | chilca
# Processing Record 41 of Set 12 | verkhnetulomskiy
# Processing Record 42 of Set 12 | lumphat
# Processing Record 43 of Set 12 | olafsvik
# Processing Record 44 of Set 12 | nisia floresta
# Processing Record 45 of Set 12 | iwanai
# Processing Record 46 of Set 12 | guadalupe y calvo
# Processing Record 47 of Set 12 | havoysund
# Processing Record 48 of Set 12 | jinchengjiang
# City not found. Skipping...
# Processing Record 49 of Set 12 | bull savanna
# Processing Record 50 of Set 12 | riohacha
# Processing Record 1 of Set 13 | kirakira
# Processing Record 2 of Set 13 | pangoa
# Processing Record 3 of Set 13 | katherine
# Processing Record 4 of Set 13 | nalut
# Processing Record 5 of Set 13 | zyryanka
# Processing Record 6 of Set 13 | ambovombe
# Processing Record 7 of Set 13 | bintulu
# Processing Record 8 of Set 13 | darhan
# Processing Record 9 of Set 13 | sitio novo do tocantins
# Processing Record 10 of Set 13 | gorom-gorom
# Processing Record 11 of Set 13 | aksu
# Processing Record 12 of Set 13 | mount gambier
# Processing Record 13 of Set 13 | bulawayo
# Processing Record 14 of Set 13 | rajula
# Processing Record 15 of Set 13 | kawalu
# Processing Record 16 of Set 13 | grand-lahou
# Processing Record 17 of Set 13 | araouane
# Processing Record 18 of Set 13 | plavsk
# Processing Record 19 of Set 13 | humberto de campos
# Processing Record 20 of Set 13 | lewiston
# Processing Record 21 of Set 13 | palana
# Processing Record 22 of Set 13 | hanzhong
# Processing Record 23 of Set 13 | sol-iletsk
# Processing Record 24 of Set 13 | ushtobe
# Processing Record 25 of Set 13 | varhaug
# Processing Record 26 of Set 13 | shu
# Processing Record 27 of Set 13 | princeville
# Processing Record 28 of Set 13 | mutsu
# Processing Record 29 of Set 13 | novi knezevac
# Processing Record 30 of Set 13 | boundiali
# Processing Record 31 of Set 13 | cockburn town
# Processing Record 32 of Set 13 | isangel
# Processing Record 33 of Set 13 | palauig
# Processing Record 34 of Set 13 | bajo baudo
# City not found. Skipping...
# Processing Record 35 of Set 13 | ilebo
# Processing Record 36 of Set 13 | kokstad
# Processing Record 37 of Set 13 | vanderhoof
# Processing Record 38 of Set 13 | kendari
# Processing Record 39 of Set 13 | balkanabat
# Processing Record 40 of Set 13 | nuevo laredo
# Processing Record 41 of Set 13 | diamantino
# Processing Record 42 of Set 13 | tucuma
# Processing Record 43 of Set 13 | souillac
# Processing Record 44 of Set 13 | the valley
# Processing Record 45 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 46 of Set 13 | pirovskoye
# Processing Record 47 of Set 13 | kirkwall
# Processing Record 48 of Set 13 | castlebar
# Processing Record 49 of Set 13 | maldonado
# Processing Record 50 of Set 13 | krasnoselkup
# Processing Record 1 of Set 14 | guntakal
# Processing Record 2 of Set 14 | salalah
# Processing Record 3 of Set 14 | liling
# Processing Record 4 of Set 14 | svetlyy
# Processing Record 5 of Set 14 | bilma
# Processing Record 6 of Set 14 | awjilah
# Processing Record 7 of Set 14 | mucurapo
# Processing Record 8 of Set 14 | timbiqui
# Processing Record 9 of Set 14 | provideniya
# Processing Record 10 of Set 14 | hobyo
# Processing Record 11 of Set 14 | svetlaya
# Processing Record 12 of Set 14 | brandon
# Processing Record 13 of Set 14 | puerto colombia
# Processing Record 14 of Set 14 | mago
# Processing Record 15 of Set 14 | vila velha
# Processing Record 16 of Set 14 | ishinomaki
# Processing Record 17 of Set 14 | farrukhnagar
# Processing Record 18 of Set 14 | emerald
# Processing Record 19 of Set 14 | inuvik
# Processing Record 20 of Set 14 | hofn
# Processing Record 21 of Set 14 | price
# Processing Record 22 of Set 14 | chazuta
# Processing Record 23 of Set 14 | tateyama
# Processing Record 24 of Set 14 | ulaangom
# Processing Record 25 of Set 14 | northam
# Processing Record 26 of Set 14 | kieta
# Processing Record 27 of Set 14 | suntar
# Processing Record 28 of Set 14 | labuhan
# Processing Record 29 of Set 14 | shakawe
# Processing Record 30 of Set 14 | aporawan
# City not found. Skipping...
# Processing Record 31 of Set 14 | jiwani
# Processing Record 32 of Set 14 | ayan
# Processing Record 33 of Set 14 | mastic beach
# Processing Record 34 of Set 14 | ligayan
# Processing Record 35 of Set 14 | caravelas
# Processing Record 36 of Set 14 | homa bay
# Processing Record 37 of Set 14 | tabuk
# Processing Record 38 of Set 14 | gornopravdinsk
# Processing Record 39 of Set 14 | darnah
# Processing Record 40 of Set 14 | neiafu
# Processing Record 41 of Set 14 | sanchor
# Processing Record 42 of Set 14 | xique-xique
# Processing Record 43 of Set 14 | myitkyina
# Processing Record 44 of Set 14 | sorland
# Processing Record 45 of Set 14 | inhambane
# Processing Record 46 of Set 14 | tallahassee
# Processing Record 47 of Set 14 | dakar
# Processing Record 48 of Set 14 | tubuala
# Processing Record 49 of Set 14 | thinadhoo
# Processing Record 50 of Set 14 | kolondieba
# Processing Record 1 of Set 15 | nador
# Processing Record 2 of Set 15 | sangueya
# Processing Record 3 of Set 15 | muscat
# Processing Record 4 of Set 15 | vao
# Processing Record 5 of Set 15 | moncton
# Processing Record 6 of Set 15 | surt
# Processing Record 7 of Set 15 | grand-santi
# Processing Record 8 of Set 15 | lyuban
# Processing Record 9 of Set 15 | laiwu
# Processing Record 10 of Set 15 | bestobe
# Processing Record 11 of Set 15 | paamiut
# Processing Record 12 of Set 15 | sungairaya
# Processing Record 13 of Set 15 | mayskiy
# Processing Record 14 of Set 15 | sivaki
# Processing Record 15 of Set 15 | roanoke rapids
# Processing Record 16 of Set 15 | miri
# Processing Record 17 of Set 15 | deputatskiy
# Processing Record 18 of Set 15 | port hardy
# Processing Record 19 of Set 15 | gardan diwal
# City not found. Skipping...
# Processing Record 20 of Set 15 | kopong
# Processing Record 21 of Set 15 | zhigansk
# Processing Record 22 of Set 15 | arvika
# Processing Record 23 of Set 15 | luanda
# Processing Record 24 of Set 15 | anchorage
# Processing Record 25 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 15 | bowen
# Processing Record 27 of Set 15 | lac du bonnet
# Processing Record 28 of Set 15 | mattru
# Processing Record 29 of Set 15 | hegang
# Processing Record 30 of Set 15 | bengkalis
# City not found. Skipping...
# Processing Record 31 of Set 15 | nuuk
# Processing Record 32 of Set 15 | puerto rondon
# Processing Record 33 of Set 15 | yining
# Processing Record 34 of Set 15 | razdolnoye
# Processing Record 35 of Set 15 | manzhouli
# Processing Record 36 of Set 15 | dyersburg
# Processing Record 37 of Set 15 | ivolginsk
# Processing Record 38 of Set 15 | mildura
# Processing Record 39 of Set 15 | takaungu
# Processing Record 40 of Set 15 | krasnoarmeyskiy
# Processing Record 41 of Set 15 | maryborough
# Processing Record 42 of Set 15 | salinopolis
# Processing Record 43 of Set 15 | praia da vitoria
# Processing Record 44 of Set 15 | yar-sale
# Processing Record 45 of Set 15 | whitley bay
# Processing Record 46 of Set 15 | bobcaygeon
# Processing Record 47 of Set 15 | billings
# Processing Record 48 of Set 15 | shanting
# Processing Record 49 of Set 15 | terenga
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Butaritari   3.0707  172.7902     82.36        75          51
# 1  Severo-Kurilsk  50.6789  156.1250     31.41        79         100
# 2        Lorengau  -2.0226  147.2712     82.96        79         100
# 3        Tiszaluc  48.0333   21.0833     39.09        80         100
# 4          Kijang  35.2442  129.2139     31.73        42          19
# 5            Sola -13.8833  167.5500     82.94        80         100
# 6          Kailua  21.4022 -157.7394     84.18        72          21
# 7    Punta Arenas -53.1500  -70.9167     53.71        82          75
# 8      Georgetown   5.4112  100.3354     76.95        91          40
# 9  Ciudad Bolivar   8.1222  -63.5497     84.13        59          86
#
#    Wind Speed Country                 Date Current Description
# 0       15.37      KI  2022-02-07 00:15:09          light rain
# 1       11.81      RU  2022-02-07 00:18:49     overcast clouds
# 2        8.50      PG  2022-02-07 00:18:25     overcast clouds
# 3       13.96      HU  2022-02-07 00:18:49          light rain
# 4        5.10      KR  2022-02-07 00:18:50          few clouds
# 5       19.80      VU  2022-02-07 00:18:51     overcast clouds
# 6        8.01      US  2022-02-07 00:18:51          few clouds
# 7        9.22      CL  2022-02-07 00:18:51       broken clouds
# 8        2.30      MY  2022-02-07 00:15:28    scattered clouds
# 9       15.75      VE  2022-02-07 00:18:52     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Butaritari      KI   3.0707  172.7902     82.36        75          51
# 1  Severo-Kurilsk      RU  50.6789  156.1250     31.41        79         100
# 2        Lorengau      PG  -2.0226  147.2712     82.96        79         100
# 3        Tiszaluc      HU  48.0333   21.0833     39.09        80         100
# 4          Kijang      KR  35.2442  129.2139     31.73        42          19
# 5            Sola      VU -13.8833  167.5500     82.94        80         100
# 6          Kailua      US  21.4022 -157.7394     84.18        72          21
# 7    Punta Arenas      CL -53.1500  -70.9167     53.71        82          75
# 8      Georgetown      MY   5.4112  100.3354     76.95        91          40
# 9  Ciudad Bolivar      VE   8.1222  -63.5497     84.13        59          86
#
#    Wind Speed Current Description
# 0       15.37          light rain
# 1       11.81     overcast clouds
# 2        8.50     overcast clouds
# 3       13.96          light rain
# 4        5.10          few clouds
# 5       19.80     overcast clouds
# 6        8.01          few clouds
# 7        9.22       broken clouds
# 8        2.30    scattered clouds
# 9       15.75     overcast clouds

# %%
pwd
# Out:
# 'C:\\Users\\Brittany\\Desktop\\Class\\World_Weather_Analysis2'

# %%
cd "C:\Users\Brittany\Desktop\Class\Weather_Database"
# Out:
# C:\Users\Brittany\Desktop\Class\Weather_Database

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
